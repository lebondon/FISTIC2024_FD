# %%
import pandas as pd


df=pd.read_csv('cars_scremated.csv')
df=df.drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#      year   Price  kms_driven fuel_type     house
# 0    2007   800.0       45000    Petrol   Hyundai
# 1    2006  4250.0          40    Diesel  Mahindra
# 2    2014  3250.0       28000    Petrol   Hyundai
# 3    2014  5750.0       36000    Diesel      Ford
# 4    2012  1750.0       41000    Diesel      Ford
# ..    ...     ...         ...       ...       ...
# 811  2011  2700.0       50000    Petrol    Maruti
# 812  2009  1100.0       30000    Diesel      Tata
# 813  2009  3000.0      132000    Petrol    Toyota
# 814  2018  2600.0       27000    Diesel      Tata
# 815  2013  3900.0       40000    Diesel  Mahindra
#
# [816 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# year          0
# Price         0
# kms_driven    0
# fuel_type     0
# house         0
# dtype: int64

# %%
df['year']=df['year'].apply(lambda x:df['year'].max()-x)

# %%
df
# Out:
#      year   Price  kms_driven fuel_type     house
# 0      12   800.0       45000    Petrol   Hyundai
# 1      13  4250.0          40    Diesel  Mahindra
# 2       5  3250.0       28000    Petrol   Hyundai
# 3       5  5750.0       36000    Diesel      Ford
# 4       7  1750.0       41000    Diesel      Ford
# ..    ...     ...         ...       ...       ...
# 811     8  2700.0       50000    Petrol    Maruti
# 812    10  1100.0       30000    Diesel      Tata
# 813    10  3000.0      132000    Petrol    Toyota
# 814     1  2600.0       27000    Diesel      Tata
# 815     6  3900.0       40000    Diesel  Mahindra
#
# [816 rows x 5 columns]

# %%
X = df.drop("Price", axis=1)
y = df['Price']

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=69)

# %%
from sklearn.pipeline import Pipeline
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.ensemble import RandomForestRegressor

cat_cols = ['fuel_type', 'house']
cont_cols = df.drop(['house', 'fuel_type','Price'], axis=1).columns

preprocessor = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore', drop="first"), cat_cols),
        ('cont', StandardScaler(), cont_cols)
    ]
)

pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', RandomForestRegressor())
])
pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   ['fuel_type', 'house']),
#                                                  ('cont', StandardScaler(),
#                                                   Index(['year', 'kms_driven'], dtype='object'))])),
#                 ('classifier', RandomForestRegressor())])

# %%
pipeline.fit(X_train,y_train)
pipeline.score(X_test,y_test)
# Out:
# 0.4703300097544729
